# %% [markdown]
# # Trouver le chemin le plus cours d'un graph avec l'aide d'un algorithme génétique

# %% [markdown]
# Implémentation du graph basé sur https://medium.com/geekculture/how-to-represent-a-graph-data-structure-in-python-9f0df57e33a2

# %% [markdown]
# Implémentation de l'algorithme génétique basé sur
# https://www.youtube.com/watch?v=nhT56blfRpE

# %% [markdown]
# ## Voici le graph que j'utilise dans le problème

# %% [markdown]
# ![image of graph](graph-path-cost.webp)

# %% [markdown]
# ### Étape 1) Prérequis

# %%
from collections import namedtuple
from functools import partial
from random import choices, randrange, randint
from random import random 
import time
from typing import Callable, List, Tuple

global DEBUG
DEBUG=False

#Debug Helper Decorator
def show_details(func):
   def wrapper(*args, **kwargs):
      global DEBUG
      DEBUG = True
      #print(f'{func.__name__} called show_details')
      fResult= func(*args,**kwargs)
      DEBUG = False
      return fResult
   return wrapper

# %% [markdown]
# ### Étape 2) La classe graph utilisé dans le problème

# %%
from random import randint

class Graph:
    def __init__(self):
        self.graph = dict()
        self.isBidirectional = False

    def addEdge(self, node1, node2, cost):
        if node1 not in self.graph:
            self.graph[node1] = []
        if node2 not in self.graph:
            self.graph[node2] = []

        self.graph[node1].append((node2, int(cost)))

        if self.isBidirectional:
            self.graph[node2].append((node1, int(cost)))  # for undirected graph

    def printGraph(self):
        for source, destination in self.graph.items():
            print(f"{source}-->{destination}")
    
    # Permet de voir si un noeud est connecté a une autre noeud
    def nodeConnected(self, nodeA: str, nodeB: str) -> bool:
        global DEBUG
        
        connectedNodes = list(self.graph.get(nodeA))
        if DEBUG==True:
            print(f'\nEvaluating nodes: {nodeA} and {nodeB}')
            print(f'{nodeA} connected nodes: {connectedNodes}')

        for nodeIndex in range(0, len(connectedNodes)):
            
            if len(connectedNodes) == 0: return False 
            
            if DEBUG==True:print(f'{nodeA} at index {nodeIndex} = {connectedNodes[nodeIndex][0]}')
            
            if connectedNodes[nodeIndex][0] == nodeB:
                if DEBUG == True: print(f'{nodeA} and {nodeB} are connected!')
                return True
        
        return False
    
    def generatePath(self, nodeA: str, nodeB: str, length: int):
        global DEBUG

        start = nodeA
        end = nodeB
        path = ""
        cost = []

        path += start
        pathLength = 1
        if DEBUG==True:
            print('\n==============================\n')
            print('Premier noeud : '+start)

        # Liste de noeuds connecté au premier noeud
        availableNodes = list(self.graph.get(start))
        if DEBUG==True:print('\tNoeuds connecté à '+start+str(availableNodes))

        while True:
            if nodeA == end:
                #print('Noeuds connecté à '+nodeA+str(availableNodes))
                if DEBUG==True:print('Dernier noeud : '+end)
                break        
            elif pathLength > length:
                break
            elif availableNodes is False:
                nodeA = nodeB
                if DEBUG==True:print('Noeud a aucune connection. nouveau noeud choisi :'+nodeA) 
            
            # Store le noeud pour être capable de retourner
            nodeB = nodeA

            # Choisi un des noeuds disponible
            randomIndexNoeud = randint(0, len(availableNodes)-1)
            nodeA = availableNodes[randomIndexNoeud][0]
            cost.append(availableNodes[randomIndexNoeud][1])
            
            path += nodeA
            pathLength += 1 
            
            #print('Noeud choisi : '+nodeA)
            
            # Liste de noeuds connecté au nouveau noeud sélectionné
            availableNodes = list(self.graph.get(nodeA))
            if DEBUG==True:print(f'\tNoeuds connecté à {nodeA}: {availableNodes}')
            
        
        #print('==============================')
        return path, cost
        
        # == Implementation checklist ==
        #   Add nodeA to path X
        #   Check connected nodes X
              # if it has no connected nodes, discard X
              # if nodeB is connected add to path
        #   Randomly select a connected node X
        #   Return path X

# %% [markdown]
# ### Étape 3) Populer le graph avec les information de graph.txt

# %%
g= Graph()
     
while True:
    answer = input("Est-ce que le graph est bi-directionnel? (y/n): ")
    
    match answer:
        case "y":
            g.isBidirectional = True
            break
        case "n":
            break
        case _:
            print("Réponse INVALIDE! svp répondez avec y ou n.")

with open("graph.txt") as f:
    lines = f.readlines()

nodes, edges = lines[0].split()

# first line is number of nodes and edges,
# pair of nodes starts from second line
for i in range(1, len(lines)):
    node1, node2, cost = lines[i].split()
    g.addEdge(node1, node2, int(cost))

# %% [markdown]
# ### Étape 4) Algorithme Génétique

# %%
nodeA = 'A'
nodeB = 'E'

Genome = List[str]
Population = List[Genome]

GenerateFunc = Callable[[int], Genome]
FitnessFunc = Callable[[Genome], int]
PopulateFunc = Callable[[int, GenerateFunc, int], Population]
SelectionFunc = Callable[[Population, FitnessFunc], Tuple[Genome, Genome]]
CrossoverFunc = Callable[[Genome, Genome], Tuple[Genome, Genome]]
MutationFunc = Callable[[Genome], Genome]

global paths
paths = []

def generate_population(size: int, genome_length: int) -> Population:
    global paths
    for _ in range(size):
        paths.append(graph_generate_genome(genome_length)) 
    return paths

def selection_pair(population: Population, fitness_func: FitnessFunc) -> Population:
    return choices(
        population=population,
        weights=[fitness_func(genome) for genome in population],
        k=2 
    )

def graph_generate_genome(length: int) -> Genome:
    global DEBUG
    global paths
    
    if DEBUG == True: DEBUG=False

    newGenome = list(g.generatePath(nodeA, nodeB, length))
    
    if DEBUG == False: DEBUG = True
    
    if DEBUG==True:
        print(f'\nGénome généré:{newGenome}')
        print('Current Population:') if paths else print('Current Population: Empty')
    
        for p in paths:
            print(p[0])
    
    if newGenome not in paths:
        return newGenome

    # Vérifie si le nouveau génome est dans la population
    for _ in range(len(paths)):
        
        if newGenome not in paths:
            break
        else:
            #print(gene)
            print(f'{newGenome[0]} already exists! Generating new genome...')
            #Regenerate a new Genome
            
            if DEBUG == True: DEBUG=False
            
            newGenome = list(g.generatePath(nodeA, nodeB, length))

            if DEBUG == False: DEBUG = True

    if DEBUG==True: print(f'{newGenome[0]} created!\tCost={sum(newGenome[1])}\n')
    
    return newGenome

@show_details
def graph_fitness(genome: Genome) -> int: 
    
    #Genomes with a lower path cost rank higher, hence the 1000/cost
    #print(f'{POPULATION_SIZE*100} / {sum(genome[1])} = {POPULATION_SIZE*100/sum(genome[1])}')
    fitnessVal = int(POPULATION_SIZE*100/sum(genome[1]))
    global DEBUG
    if DEBUG==True: print(f'\n === FITCHECK ===\n{genome[0]}\tCOST={sum(genome[1])} SCORE={fitnessVal}') 

    return fitnessVal

@show_details   
def graph_single_point_crossover(a: Genome, b: Genome) -> Tuple[Genome, Genome]:
    global DEBUG
    
    if DEBUG==True: print('\nCriss-cross time\n'+'Genome A : '+str(a)+'\tGenome B : '+str(b))
    
    # Prend la taille du génome le plus petit pour éviter index out of bound
    length = len(b[0]) if len(a[0]) > len(b[0]) else len(a[0])
    
    if DEBUG==True: print('Genome A length: '+str(len(a[0]))+' Genome B length: '+str(len(b[0])))

    if length < 2:
        return a,b

    p = randint(1, length - 1)
    
    if DEBUG==True: print('entre 0 et '+str(length -1)+' : index généré : '+str(p))

    #Parties gauche et droite du génome A et leur cout
    aLeft = a[0][0:p]
    aLCost = a[1][0:p-1]
    aRight = a[0][p:]
    aRCost = a[1][p:]
    
    #Parties gauche et droite du génome B et leur cout
    bLeft = b[0][0:p]
    bLCost = b[1][0:p-1]
    bRight = b[0][p:]
    bRCost = b[1][p:]

    # Check if genomes are the same
    if a[0] == b[0]:
        if DEBUG==True:print('Same genomes. Skipping..')
        return a,b
    
    # Check if nodes are the same
    if aLeft == bLeft:
        if DEBUG==True:print('Same first half. Skipping..')
        return a,b
    
    if aRight == bRight:
        if DEBUG==True:print('Same second half. Skipping..')
        return a,b

    # Checking genome halves compability
    if g.nodeConnected(aLeft[-1], bRight[0]) == False:
        if DEBUG==True:print(f'Incompatible genome halves ({aLeft[-1]} and {bRight[0]} don\'t connect).  Skipping..')
        return a,b # Returns Genomes as they are not compatible
    
    if g.nodeConnected(bLeft[-1], aRight[0]) == False:
        if DEBUG==True:
            print('Incompatible genome halves. Skipping..')
            print(f'Incompatible genome halves ({bLeft[-1]} and {aRight[0]} don\'t connect).  Skipping..')
        return a,b # Returns Genomes as they are not compatible

    #if we're here it means the nodes are connected and the genomes are compatible
    if DEBUG==True:
        print('Genome A Left : '+aLeft+' Cost='+str(aLCost))
        print('Genome A Right : '+aRight+' Cost='+str(aRCost))
        print('Genome B Left : '+bLeft+' Cost='+str(bLCost))
        print('Genome B Right : '+bRight+' Cost='+str(bRCost))

    #Path for new genomes
    a[0] = aLeft + bRight
    b[0] = bLeft + aRight

    if DEBUG == True: DEBUG = False
    
    #Get cost between Left and right parts
    alrCost = [get_cost(aLeft[-1], bRight[0])]
    blrCost = [get_cost(bLeft[-1], aRight[0])]
    
    DEBUG = True

    #Cost for new genomes
    a[1] = aLCost + alrCost+ bRCost
    b[1] = bLCost + blrCost + aRCost
    
    if DEBUG==True: 
        print('\nThe children have been born!\n'+'Child Genome AB : '+str(a)+'\tGenome BA : '+str(b))
    
    # Return modified genomes
    return a, b

def get_cost(l: str, r: str) -> int:
    v = 0
    d =g.graph.get(l)
    if DEBUG==True:print(l+' data: '+ str(d))

    if DEBUG==True:print(g.graph)
    for i in g.graph:
        if DEBUG==True:print(i)
        if i == l:
            for _ in range(len(d)):
                if DEBUG==True:
                    print('index:'+str(_))
                    print(str(d[_][0])+' v='+str(d[_][1]))
                            
                if d[_][0] == r:
                    v = d[_][1]
                    break
        if v != 0:
            break
    if DEBUG==True:print(v)
    return v
    
@show_details
def graph_mutation(genome: Genome, num: int=1, probability: float = 0.25) -> Genome:
    global DEBUG
    global paths
    
    for _ in range(num):
        index = randrange(len(genome[0]))
        if random() < probability: 
            if DEBUG==True:
                print('\nMUTATION\n')
                print(f'Index:{index}')
                print(f'{genome[0]} Cost: {genome[1]}')
            
            modifiablePath = list (genome[0])
            del modifiablePath[index+1:]
            #Remove cost to chopped path
            del genome[1][index:]
            
            genome[0] = ''.join(modifiablePath)
            if DEBUG==True:print(f'After delete\n{genome[0]} Cost: {genome[1]}')
            
            if DEBUG == True: DEBUG = False

            # add part of new generated genome and new cost
            path, cost = g.generatePath(genome[0][index], nodeB, GENOME_LENGTH-len(modifiablePath))
            
            DEBUG = True

            print(f'Path generated:{path}')
            print(f'Generated Path cost:{cost}')
            
            #Remove duplicated node
            del modifiablePath[-1]
            modifiablePath += path
            genome[0] = ''.join(modifiablePath)

            genome[1]+=cost
            
            paths+=genome

            if DEBUG==True:print('Path: '+str(genome[0])+' Cost: '+str(genome[1]))
    
    return genome

#@show_details
def run_evolution(
    populate_func: PopulateFunc,
    fitness_func: FitnessFunc,
    fitness_limit: int,
    selection_func: SelectionFunc = selection_pair,
    crossover_func: CrossoverFunc = graph_single_point_crossover,
    mutation_func: MutationFunc = graph_mutation,
    generation_limit: int = 100
) -> Tuple[Population, int]:
    global DEBUG
    
    if DEBUG == True : DEBUG == False
    population = populate_func()
    if DEBUG == False: DEBUG=True

    if DEBUG==True:
        print('Gen 0\nUNSORTED')
        for gene in population:
            print(gene) 

    for i in range(generation_limit):
        if DEBUG==True:print(f'\nGen {i+1}')
        
        if DEBUG == True : DEBUG == False
        
        population = sorted(
            population,
            key=lambda genome: fitness_func(genome),
            reverse=True
        )
        
        if DEBUG == False: DEBUG=True

        if DEBUG==True:
            print(f'SORTED')
            for gene in population: 
                print(gene) 

        next_generation = population[0:2]
        if DEBUG==True: print(f'TOP 2 {next_generation}')

        for j in range(int(len(population) / 2) - 1):
            parents = selection_func(population, fitness_func)
            offspring_a, offspring_b = crossover_func(parents[0], parents[1])
            offspring_a = mutation_func(offspring_a)
            offspring_b = mutation_func(offspring_b)
            next_generation += [offspring_a, offspring_b]

        population = next_generation

        if DEBUG==True:
            print('\nAfter new genes introduced')
            for gene in population:
                print(gene)
        
        if fitness_func(population[0]) >= fitness_limit:
            break
    
    if DEBUG == True : DEBUG == False
    population = sorted(
            population,
            key=lambda genome: fitness_func(genome),
            reverse=True
        )
    
    if DEBUG == False: DEBUG = True

    print('\nFinal Population')
    for gene in population:
        print(f'{gene[0]} Cost={sum(gene[1])}')    

    return population, i

start = time.time()

GENOME_LENGTH = 100#len(g.graph)
POPULATION_SIZE = 30
population, generations = run_evolution(
    populate_func=partial(
        generate_population, size=POPULATION_SIZE, genome_length=GENOME_LENGTH
    ),
    fitness_func=graph_fitness,
    fitness_limit=GENOME_LENGTH, 
    generation_limit=int(POPULATION_SIZE/2)
)

end = time.time()

print(f"number of generations: {generations}")
print(f"time: {end-start}s")
print(f"best solution: {population[0]}")
# Out:
# Génome généré:['ABE', [5, 7]]
# Current Population: Empty
#
# Génome généré:['ABE', [5, 7]]
# Current Population:
# ABE
# ABE already exists! Generating new genome...
# ABE created!	Cost=12
#
#
# Génome généré:['ABDE', [5, 2, 13]]
# Current Population:
# ABE
# ABE
#
# Génome généré:['ACDE', [9, 3, 13]]
# Current Population:
# ABE
# ABE
# ABDE
#
# Génome généré:['ABE', [5, 7]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDABE created!	Cost=20
#
#
# Génome généré:['ABDE', [5, 2, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDACDACDACDE created!	Cost=64
#
#
# Génome généré:['ABDE', [5, 2, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDACDABDE created!	Cost=41
#
#
# Génome généré:['ABDABDABDABE', [5, 2, 1, 5, 2, 1, 5, 2, 1, 5, 7]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
#
# Génome généré:['ACDACDE', [9, 3, 1, 9, 3, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
#
# Génome généré:['ACDE', [9, 3, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDABE already exists! Generating new genome...
# ACDACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDACDABDABDABDE created!	Cost=57
#
#
# Génome généré:['ABDE', [5, 2, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ABDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDACDABE created!	Cost=38
#
#
# Génome généré:['ABE', [5, 7]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ACDABE created!	Cost=25
#
#
# Génome généré:['ABDABDACDABDABE', [5, 2, 1, 5, 2, 1, 9, 3, 1, 5, 2, 1, 5, 7]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
#
# Génome généré:['ABE', [5, 7]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDACDE created!	Cost=33
#
#
# Génome généré:['ACDE', [9, 3, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDACDACDE created!	Cost=46
#
#
# Génome généré:['ACDE', [9, 3, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDABE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABDACDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABDE created!	Cost=20
#
#
# Génome généré:['ABE', [5, 7]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDABDE created!	Cost=28
#
#
# Génome généré:['ACDACDACDE', [9, 3, 1, 9, 3, 1, 9, 3, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
#
# Génome généré:['ABE', [5, 7]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
# ACDACDACDE
# ABE already exists! Generating new genome...
# ABDACDABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDACDABE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDABE already exists! Generating new genome...
# ACDACDE already exists! Generating new genome...
# ACDABDABDE created!	Cost=41
#
#
# Génome généré:['ABE', [5, 7]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
# ACDACDACDE
# ACDABDABDE
# ABE already exists! Generating new genome...
# ACDABE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABDACDACDACDE created!	Cost=59
#
#
# Génome généré:['ACDE', [9, 3, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
# ACDACDACDE
# ACDABDABDE
# ABDACDACDACDE
# ACDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDACDABDE created!	Cost=46
#
#
# Génome généré:['ACDABE', [9, 3, 1, 5, 7]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
# ACDACDACDE
# ACDABDABDE
# ABDACDACDACDE
# ACDACDABDE
# ACDABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDACDE already exists! Generating new genome...
# ABDABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDABDABE created!	Cost=33
#
#
# Génome généré:['ACDE', [9, 3, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
# ACDACDACDE
# ACDABDABDE
# ABDACDACDACDE
# ACDACDABDE
# ACDABDABE
# ACDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDABDE created!	Cost=33
#
#
# Génome généré:['ACDE', [9, 3, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
# ACDACDACDE
# ACDABDABDE
# ABDACDACDACDE
# ACDACDABDE
# ACDABDABE
# ACDABDE
# ACDE already exists! Generating new genome...
# ABDACDE already exists! Generating new genome...
# ACDABDACDABDACDE created!	Cost=67
#
#
# Génome généré:['ACDE', [9, 3, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
# ACDACDACDE
# ACDABDABDE
# ABDACDACDACDE
# ACDACDABDE
# ACDABDABE
# ACDABDE
# ACDABDACDABDACDE
# ACDE already exists! Generating new genome...
# ACDABE already exists! Generating new genome...
# ACDABDACDACDABE created!	Cost=59
#
#
# Génome généré:['ABDABDE', [5, 2, 1, 5, 2, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
# ACDACDACDE
# ACDABDABDE
# ABDACDACDACDE
# ACDACDABDE
# ACDABDABE
# ACDABDE
# ACDABDACDABDACDE
# ACDABDACDACDABE
# ABDABDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDABDABDABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ACDABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDACDABDE already exists! Generating new genome...
# ABDABDABDE created!	Cost=36
#
#
# Génome généré:['ABDE', [5, 2, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
# ACDACDACDE
# ACDABDABDE
# ABDACDACDACDE
# ACDACDABDE
# ACDABDABE
# ACDABDE
# ACDABDACDABDACDE
# ACDABDACDACDABE
# ABDABDABDE
# ABDE already exists! Generating new genome...
# ACDABDACDE created!	Cost=46
#
#
# Génome généré:['ACDE', [9, 3, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
# ACDACDACDE
# ACDABDABDE
# ABDACDACDACDE
# ACDACDABDE
# ACDABDABE
# ACDABDE
# ACDABDACDABDACDE
# ACDABDACDACDABE
# ABDABDABDE
# ACDABDACDE
# ACDE already exists! Generating new genome...
# ACDABE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDABDE already exists! Generating new genome...
# ACDABE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDABDE already exists! Generating new genome...
# ABDABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDACDE created!	Cost=38
#
#
# Génome généré:['ABDE', [5, 2, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
# ACDACDACDE
# ACDABDABDE
# ABDACDACDACDE
# ACDACDABDE
# ACDABDABE
# ACDABDE
# ACDABDACDABDACDE
# ACDABDACDACDABE
# ABDABDABDE
# ACDABDACDE
# ACDACDE
# ABDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDACDABE created!	Cost=33
#
#
# Génome généré:['ABDE', [5, 2, 13]]
# Current Population:
# ABE
# ABE
# ABDE
# ACDE
# ABDABE
# ACDACDACDACDE
# ABDACDABDE
# ABDABDABDABE
# ACDACDE
# ABDACDABDABDABDE
# ACDACDABE
# ACDABE
# ABDABDACDABDABE
# ABDACDE
# ABDACDACDE
# ABDE
# ABDABDE
# ACDACDACDE
# ACDABDABDE
# ABDACDACDACDE
# ACDACDABDE
# ACDABDABE
# ACDABDE
# ACDABDACDABDACDE
# ACDABDACDACDABE
# ABDABDABDE
# ACDABDACDE
# ACDACDE
# ABDACDABE
# ABDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABDABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDACDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABDABE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDACDABDE already exists! Generating new genome...
# ABDABE already exists! Generating new genome...
# ABDABDE already exists! Generating new genome...
# ABDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ACDACDABE already exists! Generating new genome...
# ACDABDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ACDE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABE already exists! Generating new genome...
# ABE created!	Cost=12
#
# Gen 0
# UNSORTED
# ['ABE', [5, 7]]
# ['ABE', [5, 7]]
# ['ABDE', [5, 2, 13]]
# ['ACDE', [9, 3, 13]]
# ['ABDABE', [5, 2, 1, 5, 7]]
# ['ACDACDACDACDE', [9, 3, 1, 9, 3, 1, 9, 3, 1, 9, 3, 13]]
# ['ABDACDABDE', [5, 2, 1, 9, 3, 1, 5, 2, 13]]
# ['ABDABDABDABE', [5, 2, 1, 5, 2, 1, 5, 2, 1, 5, 7]]
# ['ACDACDE', [9, 3, 1, 9, 3, 13]]
# ['ABDACDABDABDABDE', [5, 2, 1, 9, 3, 1, 5, 2, 1, 5, 2, 1, 5, 2, 13]]
# ['ACDACDABE', [9, 3, 1, 9, 3, 1, 5, 7]]
# ['ACDABE', [9, 3, 1, 5, 7]]
# ['ABDABDACDABDABE', [5, 2, 1, 5, 2, 1, 9, 3, 1, 5, 2, 1, 5, 7]]
# ['ABDACDE', [5, 2, 1, 9, 3, 13]]
# ['ABDACDACDE', [5, 2, 1, 9, 3, 1, 9, 3, 13]]
# ['ABDE', [5, 2, 13]]
# ['ABDABDE', [5, 2, 1, 5, 2, 13]]
# ['ACDACDACDE', [9, 3, 1, 9, 3, 1, 9, 3, 13]]
# ['ACDABDABDE', [9, 3, 1, 5, 2, 1, 5, 2, 13]]
# ['ABDACDACDACDE', [5, 2, 1, 9, 3, 1, 9, 3, 1, 9, 3, 13]]
# ['ACDACDABDE', [9, 3, 1, 9, 3, 1, 5, 2, 13]]
# ['ACDABDABE', [9, 3, 1, 5, 2, 1, 5, 7]]
# ['ACDABDE', [9, 3, 1, 5, 2, 13]]
# ['ACDABDACDABDACDE', [9, 3, 1, 5, 2, 1, 9, 3, 1, 5, 2, 1, 9, 3, 13]]
# ['ACDABDACDACDABE', [9, 3, 1, 5, 2, 1, 9, 3, 1, 9, 3, 1, 5, 7]]
# ['ABDABDABDE', [5, 2, 1, 5, 2, 1, 5, 2, 13]]
# ['ACDABDACDE', [9, 3, 1, 5, 2, 1, 9, 3, 13]]
# ['ACDACDE', [9, 3, 1, 9, 3, 13]]
# ['ABDACDABE', [5, 2, 1, 9, 3, 1, 5, 7]]
# ['ABE', [5, 7]]
#
# Gen 1
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDACDE	COST=64 SCORE=46
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDABE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDABDABE	COST=49 SCORE=61
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# SORTED
# ['ABE', [5, 7]]
# ['ABE', [5, 7]]
# ['ABE', [5, 7]]
# ['ABDE', [5, 2, 13]]
# ['ABDABE', [5, 2, 1, 5, 7]]
# ['ABDE', [5, 2, 13]]
# ['ACDE', [9, 3, 13]]
# ['ACDABE', [9, 3, 1, 5, 7]]
# ['ABDABDE', [5, 2, 1, 5, 2, 13]]
# ['ABDACDE', [5, 2, 1, 9, 3, 13]]
# ['ACDABDABE', [9, 3, 1, 5, 2, 1, 5, 7]]
# ['ACDABDE', [9, 3, 1, 5, 2, 13]]
# ['ABDACDABE', [5, 2, 1, 9, 3, 1, 5, 7]]
# ['ABDABDABDABE', [5, 2, 1, 5, 2, 1, 5, 2, 1, 5, 7]]
# ['ABDABDABDE', [5, 2, 1, 5, 2, 1, 5, 2, 13]]
# ['ACDACDE', [9, 3, 1, 9, 3, 13]]
# ['ACDACDABE', [9, 3, 1, 9, 3, 1, 5, 7]]
# ['ACDACDE', [9, 3, 1, 9, 3, 13]]
# ['ABDACDABDE', [5, 2, 1, 9, 3, 1, 5, 2, 13]]
# ['ACDABDABDE', [9, 3, 1, 5, 2, 1, 5, 2, 13]]
# ['ABDACDACDE', [5, 2, 1, 9, 3, 1, 9, 3, 13]]
# ['ACDACDABDE', [9, 3, 1, 9, 3, 1, 5, 2, 13]]
# ['ACDABDACDE', [9, 3, 1, 5, 2, 1, 9, 3, 13]]
# ['ABDABDACDABDABE', [5, 2, 1, 5, 2, 1, 9, 3, 1, 5, 2, 1, 5, 7]]
# ['ACDACDACDE', [9, 3, 1, 9, 3, 1, 9, 3, 13]]
# ['ABDACDABDABDABDE', [5, 2, 1, 9, 3, 1, 5, 2, 1, 5, 2, 1, 5, 2, 13]]
# ['ABDACDACDACDE', [5, 2, 1, 9, 3, 1, 9, 3, 1, 9, 3, 13]]
# ['ACDABDACDACDABE', [9, 3, 1, 5, 2, 1, 9, 3, 1, 9, 3, 1, 5, 7]]
# ['ACDACDACDACDE', [9, 3, 1, 9, 3, 1, 9, 3, 1, 9, 3, 13]]
# ['ACDABDACDABDACDE', [9, 3, 1, 5, 2, 1, 9, 3, 1, 5, 2, 1, 9, 3, 13]]
# TOP 2 [['ABE', [5, 7]], ['ABE', [5, 7]]]
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDABE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDABDABE	COST=49 SCORE=61
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDACDE	COST=64 SCORE=46
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ACDE', [9, 3, 13]]	Genome B : ['ABDABE', [5, 2, 1, 5, 7]]
# Genome A length: 4 Genome B length: 6
# entre 0 et 3 : index généré : 2
#
# Evaluating nodes: C and D
# C connected nodes: [('D', 3)]
# C at index 0 = D
# C and D are connected!
#
# Evaluating nodes: B and D
# B connected nodes: [('D', 2), ('E', 7)]
# B at index 0 = D
# B and D are connected!
# Genome A Left : AC Cost=[9]
# Genome A Right : DE Cost=[13]
# Genome B Left : AB Cost=[5]
# Genome B Right : DABE Cost=[1, 5, 7]
#
# The children have been born!
# Child Genome AB : ['ACDABE', [9, 3, 1, 5, 7]]	Genome BA : ['ABDE', [5, 2, 13]]
# graph_mutation called show_details
#
# MUTATION
#
# Index:5
# ACDABE Cost: [9, 3, 1, 5, 7]
# After delete
# ACDABE Cost: [9, 3, 1, 5, 7]
# Path generated:E
# Generated Path cost:[]
# Path: ACDABE Cost: [9, 3, 1, 5, 7]
# graph_mutation called show_details
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDABE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDABDABE	COST=49 SCORE=61
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDACDE	COST=64 SCORE=46
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ABE', [5, 7]]	Genome B : ['ACDACDE', [9, 3, 1, 9, 3, 13]]
# Genome A length: 3 Genome B length: 7
# entre 0 et 2 : index généré : 1
# Same first half. Skipping..
# graph_mutation called show_details
# graph_mutation called show_details
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDABE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDABDABE	COST=49 SCORE=61
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDACDE	COST=64 SCORE=46
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ACDACDACDE', [9, 3, 1, 9, 3, 1, 9, 3, 13]]	Genome B : ['ABDABDABDABE', [5, 2, 1, 5, 2, 1, 5, 2, 1, 5, 7]]
# Genome A length: 10 Genome B length: 12
# entre 0 et 9 : index généré : 1
# Same first half. Skipping..
# graph_mutation called show_details
# graph_mutation called show_details
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDABE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDABDABE	COST=49 SCORE=61
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDACDE	COST=64 SCORE=46
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ABE', [5, 7]]	Genome B : ['ACDACDABE', [9, 3, 1, 9, 3, 1, 5, 7]]
# Genome A length: 3 Genome B length: 9
# entre 0 et 2 : index généré : 1
# Same first half. Skipping..
# graph_mutation called show_details
# graph_mutation called show_details
#
# MUTATION
#
# Index:2
# ACDACDABE Cost: [9, 3, 1, 9, 3, 1, 5, 7]
# After delete
# ACD Cost: [9, 3]
# Path generated:DE
# Generated Path cost:[13]
# Path: ACDE Cost: [9, 3, 13]
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDABE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDABDABE	COST=49 SCORE=61
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDACDE	COST=64 SCORE=46
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ACDABDE', [9, 3, 1, 5, 2, 13]]	Genome B : ['ABE', [5, 7]]
# Genome A length: 7 Genome B length: 3
# entre 0 et 2 : index généré : 2
#
# Evaluating nodes: C and E
# C connected nodes: [('D', 3)]
# C at index 0 = D
# Incompatible genome halves (C and E don't connect).  Skipping..
# graph_mutation called show_details
#
# MUTATION
#
# Index:0
# ACDABDE Cost: [9, 3, 1, 5, 2, 13]
# After delete
# A Cost: []
# Path generated:ACDACDE
# Generated Path cost:[9, 3, 1, 9, 3, 13]
# Path: ACDACDE Cost: [9, 3, 1, 9, 3, 13]
# graph_mutation called show_details
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDABE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDABDABE	COST=49 SCORE=61
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDACDE	COST=64 SCORE=46
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ABDABDABDABE', [5, 2, 1, 5, 2, 1, 5, 2, 1, 5, 7]]	Genome B : ['ABE', [5, 7]]
# Genome A length: 12 Genome B length: 3
# entre 0 et 2 : index généré : 2
# Same first half. Skipping..
# graph_mutation called show_details
#
# MUTATION
#
# Index:4
# ABDABDABDABE Cost: [5, 2, 1, 5, 2, 1, 5, 2, 1, 5, 7]
# After delete
# ABDAB Cost: [5, 2, 1, 5]
# Path generated:BDACDE
# Generated Path cost:[2, 1, 9, 3, 13]
# Path: ABDABDACDE Cost: [5, 2, 1, 5, 2, 1, 9, 3, 13]
# graph_mutation called show_details
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDABDABE	COST=49 SCORE=61
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDACDE	COST=64 SCORE=46
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ACDABE', [9, 3, 1, 5, 7]]	Genome B : ['ABDACDABE', [5, 2, 1, 9, 3, 1, 5, 7]]
# Genome A length: 6 Genome B length: 9
# entre 0 et 5 : index généré : 5
#
# Evaluating nodes: B and D
# B connected nodes: [('D', 2), ('E', 7)]
# B at index 0 = D
# B and D are connected!
#
# Evaluating nodes: C and E
# C connected nodes: [('D', 3)]
# C at index 0 = D
# Incompatible genome halves. Skipping..
# Incompatible genome halves (C and E don't connect).  Skipping..
# graph_mutation called show_details
# graph_mutation called show_details
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDABDABE	COST=49 SCORE=61
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDACDE	COST=64 SCORE=46
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ABE', [5, 7]]	Genome B : ['ABE', [5, 7]]
# Genome A length: 3 Genome B length: 3
# entre 0 et 2 : index généré : 2
# Same genomes. Skipping..
# graph_mutation called show_details
#
# MUTATION
#
# Index:2
# ABE Cost: [5, 7]
# After delete
# ABE Cost: [5, 7]
# Path generated:E
# Generated Path cost:[]
# Path: ABE Cost: [5, 7]
# graph_mutation called show_details
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDABDABE	COST=49 SCORE=61
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDACDE	COST=64 SCORE=46
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ACDACDACDACDE', [9, 3, 1, 9, 3, 1, 9, 3, 1, 9, 3, 13]]	Genome B : ['ABDE', [5, 2, 13]]
# Genome A length: 13 Genome B length: 4
# entre 0 et 3 : index généré : 3
#
# Evaluating nodes: D and E
# D connected nodes: [('A', 1), ('E', 13)]
# D at index 0 = A
# D at index 1 = E
# D and E are connected!
#
# Evaluating nodes: D and A
# D connected nodes: [('A', 1), ('E', 13)]
# D at index 0 = A
# D and A are connected!
# Genome A Left : ACD Cost=[9, 3]
# Genome A Right : ACDACDACDE Cost=[9, 3, 1, 9, 3, 1, 9, 3, 13]
# Genome B Left : ABD Cost=[5, 2]
# Genome B Right : E Cost=[]
#
# The children have been born!
# Child Genome AB : ['ACDE', [9, 3, 13]]	Genome BA : ['ABDACDACDACDE', [5, 2, 1, 9, 3, 1, 9, 3, 1, 9, 3, 13]]
# graph_mutation called show_details
# graph_mutation called show_details
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDABDABE	COST=49 SCORE=61
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ...
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ACDACDE', [9, 3, 1, 9, 3, 13]]	Genome B : ['ACDACDE', [9, 3, 1, 9, 3, 13]]
# Genome A length: 7 Genome B length: 7
# entre 0 et 6 : index généré : 5
# Same genomes. Skipping..
# graph_mutation called show_details
#
# MUTATION
#
# Index:3
# ACDACDE Cost: [9, 3, 1, 9, 3, 13]
# After delete
# ACDA Cost: [9, 3, 1]
# Path generated:ACDACDE
# Generated Path cost:[9, 3, 1, 9, 3, 13]
# Path: ACDACDACDE Cost: [9, 3, 1, 9, 3, 1, 9, 3, 13]
# graph_mutation called show_details
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDABDABE	COST=49 SCORE=61
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ACDABE', [9, 3, 1, 5, 7]]	Genome B : ['ABDABDACDABDABE', [5, 2, 1, 5, 2, 1, 9, 3, 1, 5, 2, 1, 5, 7]]
# Genome A length: 6 Genome B length: 15
# entre 0 et 5 : index généré : 5
#
# Evaluating nodes: B and D
# B connected nodes: [('D', 2), ('E', 7)]
# B at index 0 = D
# B and D are connected!
#
# Evaluating nodes: B and E
# B connected nodes: [('D', 2), ('E', 7)]
# B at index 0 = D
# B at index 1 = E
# B and E are connected!
# Genome A Left : ACDAB Cost=[9, 3, 1, 5]
# Genome A Right : E Cost=[]
# Genome B Left : ABDAB Cost=[5, 2, 1, 5]
# Genome B Right : DACDABDABE Cost=[1, 9, 3, 1, 5, 2, 1, 5, 7]
#
# The children have been born!
# Child Genome AB : ['ACDABDACDABDABE', [9, 3, 1, 5, 2, 1, 9, 3, 1, 5, 2, 1, 5, 7]]	Genome BA : ['ABDABE', [5, 2, 1, 5, 7]]
# graph_mutation called show_details
# graph_mutation called show_details
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDABE	COST=54 SCORE=55
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ABE', [5, 7]]	Genome B : ['ABDACDACDE', [5, 2, 1, 9, 3, 1, 9, 3, 13]]
# Genome A length: 3 Genome B length: 10
# entre 0 et 2 : index généré : 2
# Same first half. Skipping..
# graph_mutation called show_details
#
# MUTATION
#
# Index:0
# ABE Cost: [5, 7]
# After delete
# A Cost: []
# Path generated:ACDACDABDE
# Generated Path cost:[9, 3, 1, 9, 3, 1, 5, 2, 13]
# Path: ACDACDABDE Cost: [9, 3, 1, 9, 3, 1, 5, 2, 13]
# graph_mutation called show_details
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDABE	COST=54 SCORE=55
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ABDABDACDE', [5, 2, 1, 5, 2, 1, 9, 3, 13]]	Genome B : ['ACDE', [9, 3, 13]]
# Genome A length: 10 Genome B length: 4
# entre 0 et 3 : index généré : 1
# Same first half. Skipping..
# graph_mutation called show_details
# graph_mutation called show_details
#
# MUTATION
#
# Index:2
# ACDE Cost: [9, 3, 13]
# After delete
# ACD Cost: [9, 3]
# Path generated:DE
# Generated Path cost:[13]
# Path: ACDE Cost: [9, 3, 13]
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDABE	COST=54 SCORE=55
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDE	COST=28 SCORE=107
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDABDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABDABDABDE	COST=57 SCORE=52
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDACDABE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDACDE	COST=67 SCORE=44
# graph_single_point_crossover called show_details
#
# Criss-cross time
# Genome A : ['ABDABDE', [5, 2, 1, 5, 2, 13]]	Genome B : ['ABDACDABDE', [5, 2, 1, 9, 3, 1, 5, 2, 13]]
# Genome A length: 7 Genome B length: 10
# entre 0 et 6 : index généré : 6
#
# Evaluating nodes: D and A
# D connected nodes: [('A', 1), ('E', 13)]
# D at index 0 = A
# D and A are connected!
#
# Evaluating nodes: D and E
# D connected nodes: [('A', 1), ('E', 13)]
# D at index 0 = A
# D at index 1 = E
# D and E are connected!
# Genome A Left : ABDABD Cost=[5, 2, 1, 5, 2]
# Genome A Right : E Cost=[]
# Genome B Left : ABDACD Cost=[5, 2, 1, 9, 3]
# Genome B Right : ABDE Cost=[5, 2, 13]
#
# The children have been born!
# Child Genome AB : ['ABDABDABDE', [5, 2, 1, 5, 2, 1, 5, 2, 13]]	Genome BA : ['ABDACDE', [5, 2, 1, 9, 3, 13]]
# graph_mutation called show_details
# graph_mutation called show_details
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDABE	COST=54 SCORE=55
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDE	COST=38 SCORE=78
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABE	COST=12 SCORE=250
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDABE	COST=33 SCORE=90
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDACDE	COST=59 SCORE=50
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDACDE	COST=51 SCORE=58
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDABDACDABDABE	COST=54 SCORE=55
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABE	COST=20 SCORE=150
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDACDABDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDACDE	COST=46 SCORE=65
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDACDE	COST=41 SCORE=73
# graph_fitness called show_details
#
#  === FITCHECK ===
# ACDE	COST=25 SCORE=120
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDABDABDE	COST=36 SCORE=83
# graph_fitness called show_details
#
#  === FITCHECK ===
# ABDACDE	COST=33 SCORE=90
#
# Final Population
# ABE Cost=12
# ABE Cost=12
# ABDE Cost=20
# ABDABE Cost=20
# ACDE Cost=25
# ACDABE Cost=25
# ACDE Cost=25
# ACDE Cost=25
# ABDACDABE Cost=33
# ABDACDE Cost=33
# ABDABDABDE Cost=36
# ACDACDE Cost=38
# ABDABDACDE Cost=41
# ABDABDACDE Cost=41
# ABDABDACDE Cost=41
# ACDACDABDE Cost=46
# ACDACDABDE Cost=46
# ACDACDABDE Cost=46
# ACDACDABDE Cost=46
# ACDACDABDE Cost=46
# ACDACDABDE Cost=46
# ACDACDABDE Cost=46
# ABDACDACDE Cost=46
# ACDACDACDE Cost=51
# ACDACDACDE Cost=51
# ACDACDACDE Cost=51
# ACDACDACDE Cost=51
# ACDABDACDABDABE Cost=54
# ACDABDACDABDABE Cost=54
# ABDACDACDACDE Cost=59
# number of generations: 0
# time: 0.008006811141967773s
# best solution: ['ABE', [5, 7]]
